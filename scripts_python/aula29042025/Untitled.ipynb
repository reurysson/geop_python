# %% [markdown]
# ## INSTITUTO FEDERAL DO PIAUÍ
# ### Curso de Tecnologia em Geoprocessamento
# ### Disciplina: Introdução à Linguagem Python para Análise de Dados
# ### Prof. Dr. Reurysson Morais
#
# ___
#
# Como citar:
# MORAIS, R. C. de S. **GEOP-Python para Análise de Dados**. Disponível em: [osf.io/8j6ng](https://osf.io/8j6ng/). DOI 10.17605/OSF.IO/8J6NG.
# ___
#
# **Objetivo**: Apresentar os recusos básicos de tratamento de strings para análise de dados.
#
# Algumas instruções:
# - Mesmo que as atividades pareçam simples, faça!;
# - Evite copiar e colar o código;
# - Sempre digite seu código ;
# - Não pule etapas.
#
# Referências
#
# DOWNEY, A. B. **Pense em Python**: pense como um cientista da computação. 3. ed. Trad. Márcio Martins. São Paulo: Novatec Editora, 2024. Uma versão online gratuita está disponível em: https://penseallen.github.io/PensePython2e/.
#
# MCKINNEY, W. **Python para Análise de Dados**: tratamento de dados com Pandas, Numpy e Ipython. 3.ed. Trad. Aldir Coelho Corrêa da Silva. São Paulo: Novatec, 2023. Uma versão online gratuita está disponível em: https://wesmckinney.com/book/
# ___

# %% [markdown]
# ## Tratamento de Strings
#
# Em análise de dados, é comum lidarmos com **dados categóricos**, como nomes, classificações e categorias textuais (nominais e ordinais).
#
# Muitas vezes, é necessário **tratar e padronizar esses textos** antes de realizar análises.
#
# A seguir, estão descritas as principais situações em que o tratamento de strings é necessário:
#
# - Contar a quantidade de caracteres em um texto
# - Eliminar espaços desnecessários
# - Colocar o texto todo em **maiúsculas** ou **minúsculas**
# - Separar partes de palavras ou frases (por exemplo, dividir nomes e sobrenomes)
# - Substituir ou remover palavras/padrões específicos
#
# O tratamento adequado de strings evita erros em agrupamentos, filtragens e análises estatísticas.

# %%
curso = "Tecnologia em Geoprocessamento"
disciplina = "Introdução à LIguagem Python para Análise de Dados"
modulo = "III"

# %%
print(type(curso))
print(type(disciplina))
print(type(modulo))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
apresentacao = """
O curso superior e tecnologia em Geoprocessamento é ofertado no 
campus Teresina Central do IFPI desde o ano 2000. Hoje, o IFPI 
conta também com uma especialização em Geoprocessamento e um mestrado 
em Análise e Planejamento Espacial, além do curso técnico em Agrimensura 
integrado ao ensino médio. 
"""

# %%
apresentacao
# Out:
# '\nO curso superior e tecnologia em Geoprocessamento é ofertado no \ncampus Teresina Central do IFPI desde o ano 2000. Hoje, o IFPI \nconta também com uma especialização em Geoprocessamento e um mestrado \nem Análise e Planejamento Espacial, além do curso técnico em Agrimensura \nintegrado ao ensino médio. \n'

# %%
print(apresentacao)
# Out:
# O curso superior e tecnologia em Geoprocessamento é ofertado no
# campus Teresina Central do IFPI desde o ano 2000. Hoje, o IFPI
# conta também com uma especialização em Geoprocessamento e um mestrado
# em Análise e Planejamento Espacial, além do curso técnico em Agrimensura
# integrado ao ensino médio.

# %%
apresentacao.count("\n")
# Out:
# 6

# %%
apresentacao.count("Geoprocessamento")
# Out:
# 2

# %%
print(curso)
# Out:
# Tecnologia em Geoprocessamento

# %%
len(curso)  #length
# Out:
# 30

# %% [raw]
# A função split segmenta uma strig a partir de determinador marcador. O default é "espaço"

# %%
cadastro = curso.split()
cadastro
# Out:
# ['Tecnologia', 'em', 'Geoprocessamento']

# %%
print(type(cadastro))
# Out:
# <class 'list'>

# %%
cadastro[2] = "Sensoriamento Remoto"

# %%
cadastro
# Out:
# ['Tecnologia', 'em', 'Sensoriamento Remoto']

# %%
cadastro[0]
# Out:
# 'Tecnologia'

# %%
cadastro[2]
# Out:
# 'Geoprocessamento'

# %%
print(list(curso))
# Out:
# ['T', 'e', 'c', 'n', 'o', 'l', 'o', 'g', 'i', 'a', ' ', 'e', 'm', ' ', 'G', 'e', 'o', 'p', 'r', 'o', 'c', 'e', 's', 's', 'a', 'm', 'e', 'n', 't', 'o']

# %%
print(curso)
# Out:
# Tecnologia em Geoprocessamento

# %%
curso[0:10]
# Out:
# 'Tecnologia'

# %%
curso[:10]
# Out:
# 'Tecnologia'

# %%
curso[14:30]
# Out:
# 'Geoprocessamento'

# %%
curso[14:]
# Out:
# 'Geoprocessamento'

# %%
curso[14:]
# Out:
# 'Geoprocessamento'

# %%
curso[-16:]
# Out:
# 'Geoprocessamento'

# %% [raw]
#  +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#  0   1   2   3   4   5   6
# -6  -5  -4  -3  -2  -1

# %%
"Geo" in curso
# Out:
# True

# %%
"geo" in curso
# Out:
# False

# %%
"Remoto" in curso
# Out:
# False

# %%
"Remoto" not in curso
# Out:
# True

# %%
curso.find("Geo")
# Out:
# 14

# %%
apresentacao.find("Ter")
# Out:
# 73

# %%
apresentacao[73:81]
# Out:
# 'Teresina'

# %%
curso
# Out:
# 'Tecnologia em Geoprocessamento'

# %%
curso.upper()
# Out:
# 'TECNOLOGIA EM GEOPROCESSAMENTO'

# %%
curso.lower()
# Out:
# 'tecnologia em geoprocessamento'

# %%
a = "Geoproxessamento"

# %%
a[6]
# Out:
# 'x'

# %%
a[6] = "c"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 a[6] = "c"
#
# TypeError: 'str' object does not support item assignment

# %%
a = a.replace("Geoproxessamento", "Geoprocessamento")
a
# Out:
# 'Geoprocessamento'

# %%
a[6]
# Out:
# 'c'

# %%
termo1 = "GEO"
termo2 = "Python"

# %%
termo = termo1 + termo2
termo
# Out:
# 'GEOPython'

# %%
edicao = "_2025.1"
termo+edicao+"_IFPI"
# Out:
# 'GEOPython_2025.1_IFPI'

# %%
nomes = ["Nome", "idade", "Grau de instrução"," sexo", "aITURA "]

# %%
nomes = [palavra.lower() for palavra in nomes]
nomes = [palavra.strip() for palavra in nomes]
nomes = [palavra.replace(" ", "_") for palavra in nomes]
nomes = [palavra.replace("ç", "c") for palavra in nomes]
nomes = [palavra.replace("ã", "a") for palavra in nomes]
nomes[4] = "altura"
nomes
# Out:
# ['nome', 'idade', 'grau_de_instrucao', 'sexo', 'altura']

# %%
nome = str(input("Digite seu nome: "))
nome = nome.upper()
nome = nome.strip()
print(f"(Nome: {nome})")
# Out:
# Digite seu nome:       reurysSOn MoraIs
# (Nome: REURYSSON MORAIS)

# %%
import unicodedata

lista2 = ["instrução", "política", "religião", "você", "cinqüenta"]

lista2 = [unicodedata.normalize("NFKD", nome).encode("ASCII", "ignore").decode("ASCII") for nome in lista2]
lista2
# Out:
# ['instrucao', 'politica', 'religiao', 'voce', 'cinquenta']
